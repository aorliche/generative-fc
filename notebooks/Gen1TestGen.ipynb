# %%
import sys

if '../server' not in sys.path:
    sys.path.append('../server')
    print(sys.path)
    
import gen
import matplotlib.pyplot as plt

img = gen.gen(1,8,0,1,'rest')

plt.imshow(img)
plt.colorbar()
plt.show()
